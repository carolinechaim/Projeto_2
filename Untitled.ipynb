# %%
import tweepy
import math
import os.path
import os
import pandas as pd
import json
from random import shuffle
import time

# %%
lista_classificada = []
elementos = pd.read_excel('FelipeNetoNaiveBayes_1.xlsx')
lista_classificada.append(elementos)
Df=pd.concat(lista_classificada,sort=False)
Df.Classificação.value_counts().plot.pie()
